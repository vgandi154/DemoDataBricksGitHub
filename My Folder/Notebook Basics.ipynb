# %%
print("Hello World")

# %%
# %sql
select "Hello World"

# %% [markdown]
# Title 1
# title **2**

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
files =dbutils.fs.ls("/databricks-datasets/")
display(files)
